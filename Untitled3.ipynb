# %%
a = 2
b = 3
print(a+b)
# Out:
# 5

# %%
# !git clone https://github.com/zahta/graph_ml.git
# Out:
# Cloning into 'graph_ml'...
# remote: Enumerating objects: 241, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 241 (delta 59), reused 117 (delta 36), pack-reused 98
# Receiving objects: 100% (241/241), 5.21 MiB | 8.10 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
# !pwd
# Out:
# /content

# %%
# !cp /content/drive/MyDrive/"Colab Notebooks"/Untitled3.ipynb
