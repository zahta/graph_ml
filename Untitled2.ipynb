# %%
a =2
b = 3
print(a+b)
# Out:
# 5

# %%
# !git clone https://github.com/zahta/graph_ml.git
# Out:
# Cloning into 'graph_ml'...
# remote: Enumerating objects: 233, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 233 (delta 55), reused 55 (delta 19), pack-reused 98
# Receiving objects: 100% (233/233), 1009.75 KiB | 20.61 MiB/s, done.
# Resolving deltas: 100% (59/59), done.

# %%
# !pwd
# Out:
# /content

# %%
# !cp /content/drive/MyDrive/Colab Notebooks/Untitled2.ipynb /content

# %%
from google.colab import drive
drive.mount('/content/drive')
